# %% [markdown]
# ### __MITRE ATT&CK Technique -> Data Source -> Event Log Mapping__
#
# This note book maps MITRE ATT&CK Techniques' Data Sources to Event Logs. The Event Log to Data Sources mapping came from Open Source Security Events Metadata (OSSEM) Detection Model.

# %%
import pandas as pd

# %%
urlfile = "https://raw.githubusercontent.com/OTRF/OSSEM-DM/main/use-cases/mitre_attack/attack_events_mapping.csv"
df_raw = pd.read_csv(urlfile, index_col=0, parse_dates=[0])
df_raw
# Out:
#                                 Component Source  \
# Data Source
# user account  user account authentication   user
# user account  user account authentication   user
# user account  user account authentication   user
# user account  user account authentication   user
# user account        user account creation   user
# ...                                   ...    ...
# group                  group modification   user
# group                  group modification   user
# group                  group modification   user
# group                  group modification   user
# group                  group modification   user
#
#                                 Relationship Target       OSSEM Id  \
# Data Source
# user account  attempted to authenticate from   port  REL-2022-0001
# user account  attempted to authenticate from   port  REL-2022-0001
# user account  attempted to authenticate from   port  REL-2022-0001
# user account  attempted to authenticate from   port  REL-2022-0001
# ...
